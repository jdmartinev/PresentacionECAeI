# %%
import pandas as pd

data = {
    "id": range(1, 11),
    "problem": [
        "High employee turnover in technical roles",
        "Delays in product delivery due to supply chain issues",
        "Low customer satisfaction with after-sales service",
        "Inefficient communication between departments",
        "Outdated IT infrastructure affecting performance",
        "Decline in online sales over the last quarter",
        "Difficulty retaining key clients amid competition",
        "Poor forecasting of inventory demand",
        "Cybersecurity vulnerabilities in legacy systems",
        "Increased operational costs due to inflation"
    ]
}

df = pd.DataFrame(data)
print(df)

df.to_csv("data/company_problems.csv", index=False)
# Out:
#    id                                            problem
# 0   1          High employee turnover in technical roles
# 1   2  Delays in product delivery due to supply chain...
# 2   3  Low customer satisfaction with after-sales ser...
# 3   4      Inefficient communication between departments
# 4   5   Outdated IT infrastructure affecting performance
# 5   6      Decline in online sales over the last quarter
# 6   7  Difficulty retaining key clients amid competition
# 7   8               Poor forecasting of inventory demand
# 8   9    Cybersecurity vulnerabilities in legacy systems
# 9  10       Increased operational costs due to inflation
